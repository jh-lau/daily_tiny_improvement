# %% [markdown]
# # 事件抽取
# - [Reference](https://blog.csdn.net/muumian123/article/details/81746583)
# - 定义
#     - 从描述事件信息的文本中抽取出事件信息并结构化呈现
# - 子任务
#     - 事件识别任务(基于单词/词汇的多分类任务)
#         - 事件类型识别
#             - ACE2005 定义了8种事件类型和33种子类型。其中，大多数事件抽取均采用33 种事件类型。事件识别是基于词的34 类(33类事件类型+None) 多元分类任务，角色分类是基于词对的36 类(35类角色类型+None) 多元分类任务
#         - 事件触发词识别
#             - 多为动词或名词
#     - 事件元素角色分类任务(基于词对的多分类任务)
#         - 事件元素
#             - 事件的参与者，主要由实体、值、时间组成。值是一种非实体的事件参与者，例如工作岗位
#         - 元素角色
#             - 事件论元在事件中充当的角色。共有35类角色，例如，攻击者 、受害者等
# - 限定/开放领域事件抽取
#     - ACE 8大类事件, 33类子事件
#         - 基于内容特征的事件抽取
#         - 基于异常检测的事件抽取
#     - 事件关系抽取
#         - 共指关系抽取
#         - 因果关系抽取
#         - 子事件关系抽取
#         - 事件时序关系抽取
# - 基于模式匹配
#     - 有监督的事件模式匹配
#         - 人工标注语料
#         - 模式学习
#         -　模式匹配
#             - PALKA模式抽取系统
#     - 弱监督的事件模式匹配
# - 基于机器学习的事件抽取
#     - 多分类问题模型，提取特征向量后使用监督分类器进行事件抽取

# %% [markdown]
# ## 军事领域事件抽取任务
# - 将文章拆分为若干个子事件
# -　子事件属性
#     - uuid[customed]
#     - date[optional]
#     - content[from competition]
#     - relationEntity[from content]
#         - example1
#             - uuid
#             - name
#             - number[optional]
#             - label
#                 - 实体识别(组织，地点，船舰)
#         - example2
#
# - 建立子事件之间关系
#     - startId
#     - endId
#
# - 实现思路
#     - 鉴于每个子事件必须有关联实体，因此根据ltp工具识别出来的名词/动词进行触发，以含有该实体的最小单位为一个子事件，即：以能抽出至少一个实体为标准定义一个子事件
#     - 文章分句(句号，感叹号，问号)，暂定各个句子为一个子事件(id2event字典)
#     - 对各个子事件进行带词性标注的句法依存分析，得到诸如地名(ns, nsf..)，组织(nt, ntc, nto..)，人物(nr, nrf..)，时间事件(nt)以及其他专有名词(nz, nx)的实体
#         - 专有名词部分，需要军事领域词库(组织名，武器名等)支持保证分词的准确度
#         - 子事件主语为代词的指代消解：结合每篇文章标题与已抽取的子事件实体，来进一步制定规则进行代词替换
#             - 如本分句主语代词大概率为上一句的主语，若上一句主语为名词，若上一句存在多个主语，则需要进一步判断
#     - 若单个分句分析未得到以上触发词(动词、名词),则默认此分句不构成一个子事件，将其并入下一个分句，或者舍弃
#     - 子事件之间关系建立(event2id字典)
#         - 暂定为按照文章顺序确定各个子事件为依次顺承关系

# %% [markdown]
# # 工具导入

# %%
import re
from pyhanlp import *
from pprint import pprint
import json
from collections import defaultdict
import datetime
from copy import deepcopy

# %% [markdown]
# # Helper function

# %%
def split_sents(content):
        return [sentence.replace('　','') for sentence in re.split(r'[？?！!。；;：:\n\r]', content) if sentence]

# %%
temp = {"brief":"四百二十七","parameter":"排量：11000t。","title":"蒙特利","url":"http://www.hazegray.org/danfs/carriers/cvl26.htm","content":["摘自：《美国海军战斗舰词典》，第四卷（1969年），页。","四百二十七","CVL-26型","纽约造船公司于1941年12月29日在新泽西州卡姆登市建立了代顿（CL-78）；于1942年3月27日重新分类为CV-26；于1942年3月31日更名为蒙特利；于1943年2月28日下水；由P.N.L.贝林格夫人赞助；并于1943年6月17日委任莱斯特T.亨特上尉指挥。","蒙特利号于1943年7月15日重新定级为CVL-26，在服役不久后，在安定下来后，离开费城前往西太平洋。她于1943年11月19日到达吉尔伯茨号，及时帮助马金岛安全。作为TG 37.2的一部分，她参加了12月25日对新爱尔兰Kavieng的罢工，并支持在Kwajalein和Eniwetok降落，直到1944年2月8日。1944年2月至7月，这艘轻型航母在卡罗琳、马里亚纳、新几内亚北部和博宁群岛的突袭中与58特遣部队一起行动。在此期间，她还参与了4月29日和30日的菲律宾海战役。","蒙特利随后驶往珍珠港进行检修，于8月29日再次启航。她于9月3日发动了对威克岛的袭击，随后加入了第38特遣部队，并参加了对菲律宾南部和琉球的袭击。1944年10月至12月在菲律宾度过，首先支持莱特，然后支持民都洛登陆。","尽管敌机无法摧毁蒙特利，但她并没有毫发无损地完成第一年的服役。去年12月，她驶进了一条呼啸的台风路径，风速超过100节!风暴持续了两天之久，在最高峰时，几架飞机从缆绳上脱落，导致机库甲板上发生了几起火灾。1945年1月，蒙特利抵达华盛顿州布雷默顿进行大修?她从5月9日至6月1日重新加入58特遣部队，并支持冲绳的行动，对N ansei Shoto和d Kyushu发动了打击！7月1日至8月15日，她重返38特遣部队，参加了对本州和北海道的最后一次打击？","她于9月7日离开日本水域，在东京出兵，然后清蒸回家，10月17日抵达纽约市。蒙特利留下了令人印象深刻、令人羡慕的战绩。她的飞机击沉了五艘敌舰，并损坏了其他战舰。她负责摧毁数千吨日本船只、数百架飞机和重要的工业综合体。她被分配到“魔毯”任务，并在那不勒斯和诺福克之间进行了几次航行。她于1947年2月11日退役，并被分配到费城大西洋后备舰队。","随着朝鲜战争的爆发，蒙特利于1950年9月15日重新投入使用。她于1951年1月3日离开诺福克，前往佛罗里达州彭萨科拉，在海军训练司令部的领导下，在那里工作了4年，训练了数千名海军航空学员、学生飞行员和直升机学员。1954年10月1日至11日，她参加了洪都拉斯的一次洪灾救援任务。她于1955年6月9日离开彭萨科拉，重新加入费城大西洋预备舰队。她于1956年1月16日退役。1959年5月15日，她被重新归类为AVT-2，直到1969年仍在费城停泊。","蒙特利在第二次世界大战中获得了11颗战斗之星。","由Michael Hansen 72667.1530@compuserve.com转录"]}
string = temp['content'][3:]
pprint(temp)
pprint(string)
# Out:
# {'brief': '四百二十七',
#  'content': ['摘自：《美国海军战斗舰词典》，第四卷（1969年），页。',
#              '四百二十七',
#              'CVL-26型',
#              '纽约造船公司于1941年12月29日在新泽西州卡姆登市建立了代顿（CL-78）；于1942年3月27日重新分类为CV-26；于1942年3月31日更名为蒙特利；于1943年2月28日下水；由P.N.L.贝林格夫人赞助；并于1943年6月17日委任莱斯特T.亨特上尉指挥。',
#              '蒙特利号于1943年7月15日重新定级为CVL-26，在服役不久后，在安定下来后，离开费城前往西太平洋。她于1943年11月19日到达吉尔伯茨号，及时帮助马金岛安全。作为TG '
#              '37.2的一部分，她参加了12月25日对新爱尔兰Kavieng的罢工，并支持在Kwajalein和Eniwetok降落，直到1944年2月8日。1944年2月至7月，这艘轻型航母在卡罗琳、马里亚纳、新几内亚北部和博宁群岛的突袭中与58特遣部队一起行动。在此期间，她还参与了4月29日和30日的菲律宾海战役。',
#              '蒙特利随后驶往珍珠港进行检修，于8月29日再次启航。她于9月3日发动了对威克岛的袭击，随后加入了第38特遣部队，并参加了对菲律宾南部和琉球的袭击。1944年10月至12月在菲律宾度过，首先支持莱特，然后支持民都洛登陆。',
#              '尽管敌机无法摧毁蒙特利，但她并没有毫发无损地完成第一年的服役。去年12月，她驶进了一条呼啸的台风路径，风速超过100节!风暴持续了两天之久，在最高峰时，几架飞机从缆绳上脱落，导致机库甲板上发生了几起火灾。1945年1月，蒙特利抵达华盛顿州布雷默顿进行大修?她从5月9日至6月1日重新加入58特遣部队，并支持冲绳的行动，对N '
#              'ansei Shoto和d '
#              'Kyushu发动了打击！7月1日至8月15日，她重返38特遣部队，参加了对本州和北海道的最后一次打击？',
#              '她于9月7日离开日本水域，在东京出兵，然后清蒸回家，10月17日抵达纽约市。蒙特利留下了令人印象深刻、令人羡慕的战绩。她的飞机击沉了五艘敌舰，并损坏了其他战舰。她负责摧毁数千吨日本船只、数百架飞机和重要的工业综合体。她被分配到“魔毯”任务，并在那不勒斯和诺福克之间进行了几次航行。她于1947年2月11日退役，并被分配到费城大西洋后备舰队。',
#              '随着朝鲜战争的爆发，蒙特利于1950年9月15日重新投入使用。她于1951年1月3日离开诺福克，前往佛罗里达州彭萨科拉，在海军训练司令部的领导下，在那里工作了4年，训练了数千名海军航空学员、学生飞行员和直升机学员。1954年10月1日至11日，她参加了洪都拉斯的一次洪灾救援任务。她于1955年6月9日离开彭萨科拉，重新加入费城大西洋预备舰队。她于1956年1月16日退役。1959年5月15日，她被重新归类为AVT-2，直到1969年仍在费城停泊。',
#              '蒙特利在第二次世界大战中获得了11颗战斗之星。',
#              '由Michael Hansen 72667.1530@compuserve.com转录'],
#  'parameter': '排量：11000t。',
#  'title': '蒙特利',
#  'url': 'http://www.hazegray.org/danfs/carriers/cvl26.htm'}
# ['纽约造船公司于1941年12月29日在新泽西州卡姆登市建立了代顿（CL-78）；于1942年3月27日重新分类为CV-26；于1942年3月31日更名为蒙特利；于1943年2月28日下水；由P.N.L.贝林格夫人赞助；并于1943年6月17日委任莱斯特T.亨特上尉指挥。',
#  '蒙特利号于1943年7月15日重新定级为CVL-26，在服役不久后，在安定下来后，离开费城前往西太平洋。她于1943年11月19日到达吉尔伯茨号，及时帮助马金岛安全。作为TG '
#  '37.2的一部分，她参加了12月25日对新爱尔兰Kavieng的罢工，并支持在Kwajalein和Eniwetok降落，直到1944年2月8日。1944年2月至7月，这艘轻型航母在卡罗琳、马里亚纳、新几内亚北部和博宁群岛的突袭中与58特遣部队一起行动。在此期间，她还参与了4月29日和30日的菲律宾海战役。',
#  '蒙特利随后驶往珍珠港进行检修，于8月29日再次启航。她于9月3日发动了对威克岛的袭击，随后加入了第38特遣部队，并参加了对菲律宾南部和琉球的袭击。1944年10月至12月在菲律宾度过，首先支持莱特，然后支持民都洛登陆。',
#  '尽管敌机无法摧毁蒙特利，但她并没有毫发无损地完成第一年的服役。去年12月，她驶进了一条呼啸的台风路径，风速超过100节!风暴持续了两天之久，在最高峰时，几架飞机从缆绳上脱落，导致机库甲板上发生了几起火灾。1945年1月，蒙特利抵达华盛顿州布雷默顿进行大修?她从5月9日至6月1日重新加入58特遣部队，并支持冲绳的行动，对N '
#  'ansei Shoto和d Kyushu发动了打击！7月1日至8月15日，她重返38特遣部队，参加了对本州和北海道的最后一次打击？',
#  '她于9月7日离开日本水域，在东京出兵，然后清蒸回家，10月17日抵达纽约市。蒙特利留下了令人印象深刻、令人羡慕的战绩。她的飞机击沉了五艘敌舰，并损坏了其他战舰。她负责摧毁数千吨日本船只、数百架飞机和重要的工业综合体。她被分配到“魔毯”任务，并在那不勒斯和诺福克之间进行了几次航行。她于1947年2月11日退役，并被分配到费城大西洋后备舰队。',
#  '随着朝鲜战争的爆发，蒙特利于1950年9月15日重新投入使用。她于1951年1月3日离开诺福克，前往佛罗里达州彭萨科拉，在海军训练司令部的领导下，在那里工作了4年，训练了数千名海军航空学员、学生飞行员和直升机学员。1954年10月1日至11日，她参加了洪都拉斯的一次洪灾救援任务。她于1955年6月9日离开彭萨科拉，重新加入费城大西洋预备舰队。她于1956年1月16日退役。1959年5月15日，她被重新归类为AVT-2，直到1969年仍在费城停泊。',
#  '蒙特利在第二次世界大战中获得了11颗战斗之星。',
#  '由Michael Hansen 72667.1530@compuserve.com转录']

# %%
split_events = split_sents(''.join(string))

# %%
id2event = {split_events.index(r): r for r in split_events}
id2event
# Out:
# {0: '纽约造船公司于1941年12月29日在新泽西州卡姆登市建立了代顿（CL-78）',
#  1: '于1942年3月27日重新分类为CV-26',
#  2: '于1942年3月31日更名为蒙特利',
#  3: '于1943年2月28日下水',
#  4: '由P.N.L.贝林格夫人赞助',
#  5: '并于1943年6月17日委任莱斯特T.亨特上尉指挥',
#  6: '蒙特利号于1943年7月15日重新定级为CVL-26，在服役不久后，在安定下来后，离开费城前往西太平洋',
#  7: '她于1943年11月19日到达吉尔伯茨号，及时帮助马金岛安全',
#  8: '作为TG 37.2的一部分，她参加了12月25日对新爱尔兰Kavieng的罢工，并支持在Kwajalein和Eniwetok降落，直到1944年2月8日',
#  9: '1944年2月至7月，这艘轻型航母在卡罗琳、马里亚纳、新几内亚北部和博宁群岛的突袭中与58特遣部队一起行动',
#  10: '在此期间，她还参与了4月29日和30日的菲律宾海战役',
#  11: '蒙特利随后驶往珍珠港进行检修，于8月29日再次启航',
#  12: '她于9月3日发动了对威克岛的袭击，随后加入了第38特遣部队，并参加了对菲律宾南部和琉球的袭击',
#  13: '1944年10月至12月在菲律宾度过，首先支持莱特，然后支持民都洛登陆',
#  14: '尽管敌机无法摧毁蒙特利，但她并没有毫发无损地完成第一年的服役',
#  15: '去年12月，她驶进了一条呼啸的台风路径，风速超过100节',
#  16: '风暴持续了两天之久，在最高峰时，几架飞机从缆绳上脱落，导致机库甲板上发生了几起火灾',
#  17: '1945年1月，蒙特利抵达华盛顿州布雷默顿进行大修',
#  18: '她从5月9日至6月1日重新加入58特遣部队，并支持冲绳的行动，对N ansei Shoto和d Kyushu发动了打击',
#  19: '7月1日至8月15日，她重返38特遣部队，参加了对本州和北海道的最后一次打击',
#  20: '她于9月7日离开日本水域，在东京出兵，然后清蒸回家，10月17日抵达纽约市',
#  21: '蒙特利留下了令人印象深刻、令人羡慕的战绩',
#  22: '她的飞机击沉了五艘敌舰，并损坏了其他战舰',
#  23: '她负责摧毁数千吨日本船只、数百架飞机和重要的工业综合体',
#  24: '她被分配到“魔毯”任务，并在那不勒斯和诺福克之间进行了几次航行',
#  25: '她于1947年2月11日退役，并被分配到费城大西洋后备舰队',
#  26: '随着朝鲜战争的爆发，蒙特利于1950年9月15日重新投入使用',
#  27: '她于1951年1月3日离开诺福克，前往佛罗里达州彭萨科拉，在海军训练司令部的领导下，在那里工作了4年，训练了数千名海军航空学员、学生飞行员和直升机学员',
#  28: '1954年10月1日至11日，她参加了洪都拉斯的一次洪灾救援任务',
#  29: '她于1955年6月9日离开彭萨科拉，重新加入费城大西洋预备舰队',
#  30: '她于1956年1月16日退役',
#  31: '1959年5月15日，她被重新归类为AVT-2，直到1969年仍在费城停泊',
#  32: '蒙特利在第二次世界大战中获得了11颗战斗之星',
#  33: '由Michael Hansen 72667.1530@compuserve.com转录'}

# %% [markdown]
# # 抽取子事件及其属性

# %%
target_label = {
        '人物': {'nr', 'nr1', 'nr2', 'nrf', 'nrj'},
        '组织机构': {'nt', 'ntc', 'nto'},
        '地点': {'ns', 'nsf'},
        '武器': {'nz'},
        '候选': {'nx', 'n'}}
entity_set  = set()
[entity_set.update(a) for a in target_label.values()]
entity_set
# Out:
# {'n',
#  'nr',
#  'nr1',
#  'nr2',
#  'nrf',
#  'nrj',
#  'ns',
#  'nsf',
#  'nt',
#  'ntc',
#  'nto',
#  'nx',
#  'nz'}

# %%
result = []
for key, value in id2event.items():
    event_dict = defaultdict(list)
    parser = HanLP.parseDependency(value)
    
    # check if target entity exists
    entity = set([each.POSTAG for each in parser])
    if not (entity & entity_set):
        print("Not a sub-event")
        continue
    
    event_dict['uuid'] = key
    
    event_dict['content'] = value
    
    date_pattern = re.compile(r'[\d]*[年|月|日]*[\d]*[月]+[\d]*[年|月|日]*')
    event_dict['date'].extend(date_pattern.findall(value))
    
    event_dict['relationEntity'] = []
    
    for index, each in enumerate(parser):
        relationEntity = defaultdict(list)
        for key, value in target_label.items():
            if each.POSTAG in value:
                relationEntity['uuid'] = index
                relationEntity['name'] = each.LEMMA
                # optional
#                 relationEntity['number'] = 0
                relationEntity['label'] = key
        if relationEntity:
            event_dict['relationEntity'].append(relationEntity)
    
    result.append(event_dict)
    print(event_dict)
    print(parser)
    print()
    print()
# Out:
# defaultdict(<class 'list'>, {'uuid': 0, 'content': '纽约造船公司于1941年12月29日在新泽西州卡姆登市建立了代顿（CL-78）', 'date': ['1941年12月29日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 0, 'name': '纽约', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 1, 'name': '造船公司', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 5, 'name': '新泽西州', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 6, 'name': '卡姆', 'label': '人物'}), defaultdict(<class 'list'>, {'uuid': 7, 'name': '登市', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 10, 'name': '代顿', 'label': '武器'}), defaultdict(<class 'list'>, {'uuid': 12, 'name': 'CL', 'label': '候选'})]})
# 1	纽约	纽约	ns	ns	_	2	定中关系	_	_
# 2	造船公司	造船公司	n	n	_	9	主谓关系	_	_
# 3	于	于	p	p	_	9	状中结构	_	_
# 4	1941年12月29日	1941年12月29日	nt	t	_	3	介宾关系	_	_
# 5	在	在	p	p	_	9	状中结构	_	_
# 6	新泽西州	新泽西州	ns	ns	_	7	定中关系	_	_
# 7	卡姆	卡姆	nh	nrf	_	8	定中关系	_	_
# 8	登市	登市	ns	ns	_	5	介宾关系	_	_
# 9	建立	建立	v	v	_	0	核心关系	_	_
# 10	了	了	u	u	_	9	右附加关系	_	_
# 11	代顿	代顿	nz	nz	_	9	动宾关系	_	_
# 12	（	（	wp	w	_	13	标点符号	_	_
# 13	CL	CL	ws	nx	_	11	并列关系	_	_
# 14	-	-	wp	w	_	13	标点符号	_	_
# 15	78	78	m	m	_	13	并列关系	_	_
# 16	）	）	wp	w	_	13	标点符号	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 1, 'content': '于1942年3月27日重新分类为CV-26', 'date': ['1942年3月27日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 5, 'name': 'CV', 'label': '候选'})]})
# 1	于	于	p	p	_	4	状中结构	_	_
# 2	1942年3月27日	1942年3月27日	nt	t	_	1	介宾关系	_	_
# 3	重新	重新	d	d	_	4	状中结构	_	_
# 4	分类	分类	v	v	_	0	核心关系	_	_
# 5	为	为	p	p	_	4	动补结构	_	_
# 6	CV	CV	ws	nx	_	5	介宾关系	_	_
# 7	-	-	wp	w	_	4	标点符号	_	_
# 8	26	26	m	m	_	4	并列关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 2, 'content': '于1942年3月31日更名为蒙特利', 'date': ['1942年3月31日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 4, 'name': '蒙特利', 'label': '人物'})]})
# 1	于	于	p	p	_	3	状中结构	_	_
# 2	1942年3月31日	1942年3月31日	nt	t	_	1	介宾关系	_	_
# 3	更名	更名	v	v	_	0	核心关系	_	_
# 4	为	为	v	v	_	3	动补结构	_	_
# 5	蒙特利	蒙特利	nh	nrf	_	4	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 3, 'content': '于1943年2月28日下水', 'date': ['1943年2月28日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 2, 'name': '下水', 'label': '候选'})]})
# 1	于	于	p	p	_	3	状中结构	_	_
# 2	1943年2月28日	1943年2月28日	nt	t	_	1	介宾关系	_	_
# 3	下水	下水	n	n	_	0	核心关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 4, 'content': '由P.N.L.贝林格夫人赞助', 'date': [], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 2, 'name': 'N', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 5, 'name': '夫人', 'label': '候选'})]})
# 1	由	由	p	p	_	7	状中结构	_	_
# 2	P.	P.	m	m	_	3	定中关系	_	_
# 3	N	N	ws	nx	_	1	介宾关系	_	_
# 4	.	.	wp	w	_	1	标点符号	_	_
# 5	L.贝林格	L.贝林格	u	u	_	6	定中关系	_	_
# 6	夫人	夫人	n	n	_	7	主谓关系	_	_
# 7	赞助	赞助	v	v	_	0	核心关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 5, 'content': '并于1943年6月17日委任莱斯特T.亨特上尉指挥', 'date': ['1943年6月17日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 4, 'name': '莱斯特T.亨特', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 5, 'name': '上尉', 'label': '候选'})]})
# 1	并于	并于	c	c	_	4	状中结构	_	_
# 2	1943年6月17	1943年6月17	m	m	_	3	定中关系	_	_
# 3	日	日	q	q	_	4	状中结构	_	_
# 4	委任	委任	v	v	_	0	核心关系	_	_
# 5	莱斯特T.亨特	莱斯特T.亨特	ns	ns	_	6	定中关系	_	_
# 6	上尉	上尉	n	n	_	4	兼语	_	_
# 7	指挥	指挥	v	v	_	4	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 6, 'content': '蒙特利号于1943年7月15日重新定级为CVL-26，在服役不久后，在安定下来后，离开费城前往西太平洋', 'date': ['1943年7月15日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 0, 'name': '蒙特利', 'label': '人物'}), defaultdict(<class 'list'>, {'uuid': 7, 'name': 'CVL-26', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 20, 'name': '费城', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 22, 'name': '西太平洋', 'label': '地点'})]})
# 1	蒙特利	蒙特利	nh	nrf	_	2	主谓关系	_	_
# 2	号	号	v	v	_	0	核心关系	_	_
# 3	于	于	p	p	_	2	动补结构	_	_
# 4	1943年7月15日	1943年7月15日	nt	t	_	3	介宾关系	_	_
# 5	重新	重新	d	d	_	6	状中结构	_	_
# 6	定级	定级	v	v	_	2	并列关系	_	_
# 7	为	为	p	p	_	6	动补结构	_	_
# 8	CVL-26	CVL-26	ws	nx	_	7	介宾关系	_	_
# 9	，	，	wp	w	_	2	标点符号	_	_
# 10	在	在	p	p	_	20	状中结构	_	_
# 11	服役	服役	v	v	_	13	定中关系	_	_
# 12	不久	不久	m	m	_	11	动补结构	_	_
# 13	后	后	nd	f	_	10	介宾关系	_	_
# 14	，	，	wp	w	_	10	标点符号	_	_
# 15	在	在	p	p	_	20	状中结构	_	_
# 16	安定	安定	v	v	_	18	定中关系	_	_
# 17	下来	下来	v	v	_	16	动补结构	_	_
# 18	后	后	nd	f	_	15	介宾关系	_	_
# 19	，	，	wp	w	_	15	标点符号	_	_
# 20	离开	离开	v	v	_	2	并列关系	_	_
# 21	费城	费城	ns	ns	_	20	动宾关系	_	_
# 22	前往	前往	v	v	_	20	并列关系	_	_
# 23	西太平洋	西太平洋	ns	ns	_	22	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 7, 'content': '她于1943年11月19日到达吉尔伯茨号，及时帮助马金岛安全', 'date': ['1943年11月19日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 4, 'name': '吉尔伯茨号', 'label': '武器'}), defaultdict(<class 'list'>, {'uuid': 8, 'name': '马金岛', 'label': '地点'})]})
# 1	她	她	r	r	_	4	主谓关系	_	_
# 2	于	于	p	p	_	4	状中结构	_	_
# 3	1943年11月19日	1943年11月19日	nt	t	_	2	介宾关系	_	_
# 4	到达	到达	v	v	_	0	核心关系	_	_
# 5	吉尔伯茨号	吉尔伯茨号	nz	nz	_	4	动宾关系	_	_
# 6	，	，	wp	w	_	4	标点符号	_	_
# 7	及时	及时	a	ad	_	8	状中结构	_	_
# 8	帮助	帮助	v	v	_	4	并列关系	_	_
# 9	马金岛	马金岛	ns	ns	_	10	主谓关系	_	_
# 10	安全	安全	a	an	_	8	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 8, 'content': '作为TG 37.2的一部分，她参加了12月25日对新爱尔兰Kavieng的罢工，并支持在Kwajalein和Eniwetok降落，直到1944年2月8日', 'date': ['12月25日', '1944年2月8日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 10, 'name': '新爱尔兰', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 11, 'name': 'Kavieng', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 18, 'name': 'Kwajalein', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 20, 'name': 'Eniwetok', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 21, 'name': '降落', 'label': '候选'})]})
# 1	作为	作为	v	v	_	0	核心关系	_	_
# 2	TG 37.2	TG 37.2	m	m	_	4	定中关系	_	_
# 3	的	的	u	u	_	2	右附加关系	_	_
# 4	一部分	一部分	m	m	_	1	动宾关系	_	_
# 5	，	，	wp	w	_	1	标点符号	_	_
# 6	她	她	r	r	_	7	主谓关系	_	_
# 7	参加	参加	v	v	_	1	并列关系	_	_
# 8	了	了	u	u	_	7	右附加关系	_	_
# 9	12月25日	12月25日	nt	t	_	14	定中关系	_	_
# 10	对	对	p	p	_	14	定中关系	_	_
# 11	新爱尔兰	新爱尔兰	ns	ns	_	12	定中关系	_	_
# 12	Kavieng	Kavieng	ws	nx	_	10	介宾关系	_	_
# 13	的	的	u	u	_	10	右附加关系	_	_
# 14	罢工	罢工	v	vn	_	7	动宾关系	_	_
# 15	，	，	wp	w	_	7	标点符号	_	_
# 16	并	并	c	c	_	17	状中结构	_	_
# 17	支持	支持	v	v	_	7	并列关系	_	_
# 18	在	在	p	p	_	22	状中结构	_	_
# 19	Kwajalein	Kwajalein	ws	nx	_	22	主谓关系	_	_
# 20	和	和	c	c	_	21	左附加关系	_	_
# 21	Eniwetok	Eniwetok	ws	nx	_	19	并列关系	_	_
# 22	降落	降落	n	n	_	17	动宾关系	_	_
# 23	，	，	wp	w	_	7	标点符号	_	_
# 24	直到	直到	v	v	_	7	并列关系	_	_
# 25	1944年2月8日	1944年2月8日	nt	t	_	24	介宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 9, 'content': '1944年2月至7月，这艘轻型航母在卡罗琳、马里亚纳、新几内亚北部和博宁群岛的突袭中与58特遣部队一起行动', 'date': ['1944年2月', '7月'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 7, 'name': '航母', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 9, 'name': '卡罗琳', 'label': '人物'}), defaultdict(<class 'list'>, {'uuid': 11, 'name': '马里亚纳', 'label': '人物'}), defaultdict(<class 'list'>, {'uuid': 13, 'name': '新几内亚', 'label': '武器'}), defaultdict(<class 'list'>, {'uuid': 17, 'name': '群岛', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 23, 'name': '特遣部队', 'label': '候选'})]})
# 1	1944年2月	1944年2月	nt	t	_	2	状中结构	_	_
# 2	至	至	p	p	_	26	状中结构	_	_
# 3	7月	7月	nt	t	_	2	介宾关系	_	_
# 4	，	，	wp	w	_	2	标点符号	_	_
# 5	这	这	r	r	_	6	定中关系	_	_
# 6	艘	艘	q	q	_	8	定中关系	_	_
# 7	轻型	轻型	b	b	_	8	定中关系	_	_
# 8	航母	航母	n	n	_	26	主谓关系	_	_
# 9	在	在	p	p	_	26	状中结构	_	_
# 10	卡罗琳	卡罗琳	nh	nrf	_	20	定中关系	_	_
# 11	、	、	wp	w	_	12	标点符号	_	_
# 12	马里亚纳	马里亚纳	nh	nr	_	10	并列关系	_	_
# 13	、	、	wp	w	_	15	标点符号	_	_
# 14	新几内亚	新几内亚	nz	nz	_	15	定中关系	_	_
# 15	北部	北部	nd	f	_	10	并列关系	_	_
# 16	和	和	c	c	_	18	左附加关系	_	_
# 17	博宁	博宁	nz	nhm	_	18	定中关系	_	_
# 18	群岛	群岛	n	n	_	10	并列关系	_	_
# 19	的	的	u	u	_	10	右附加关系	_	_
# 20	突袭	突袭	v	vn	_	21	定中关系	_	_
# 21	中	中	nd	f	_	9	介宾关系	_	_
# 22	与	与	p	p	_	26	状中结构	_	_
# 23	58	58	m	m	_	24	定中关系	_	_
# 24	特遣部队	特遣部队	n	n	_	22	介宾关系	_	_
# 25	一起	一起	d	d	_	26	状中结构	_	_
# 26	行动	行动	v	v	_	0	核心关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 10, 'content': '在此期间，她还参与了4月29日和30日的菲律宾海战役', 'date': ['4月29日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 11, 'name': '菲律宾海', 'label': '武器'}), defaultdict(<class 'list'>, {'uuid': 12, 'name': '战役', 'label': '候选'})]})
# 1	在此期间	在此期间	i	l	_	5	状中结构	_	_
# 2	，	，	wp	w	_	1	标点符号	_	_
# 3	她	她	r	r	_	5	主谓关系	_	_
# 4	还	还	d	d	_	5	状中结构	_	_
# 5	参与	参与	v	v	_	0	核心关系	_	_
# 6	了	了	u	u	_	5	右附加关系	_	_
# 7	4月	4月	nt	t	_	8	定中关系	_	_
# 8	29日	29日	nt	t	_	13	定中关系	_	_
# 9	和	和	c	c	_	10	左附加关系	_	_
# 10	30日	30日	nt	t	_	8	并列关系	_	_
# 11	的	的	u	u	_	8	右附加关系	_	_
# 12	菲律宾海	菲律宾海	nz	nz	_	13	定中关系	_	_
# 13	战役	战役	n	n	_	5	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 11, 'content': '蒙特利随后驶往珍珠港进行检修，于8月29日再次启航', 'date': ['8月29日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 0, 'name': '蒙特利', 'label': '人物'}), defaultdict(<class 'list'>, {'uuid': 3, 'name': '珍珠港', 'label': '地点'})]})
# 1	蒙特利	蒙特利	nh	nrf	_	3	主谓关系	_	_
# 2	随后	随后	d	d	_	3	状中结构	_	_
# 3	驶往	驶往	v	v	_	0	核心关系	_	_
# 4	珍珠港	珍珠港	ns	ns	_	3	动宾关系	_	_
# 5	进行	进行	v	v	_	3	并列关系	_	_
# 6	检修	检修	v	vn	_	5	动宾关系	_	_
# 7	，	，	wp	w	_	3	标点符号	_	_
# 8	于	于	p	p	_	11	状中结构	_	_
# 9	8月29日	8月29日	nt	t	_	8	介宾关系	_	_
# 10	再次	再次	d	d	_	11	状中结构	_	_
# 11	启航	启航	v	v	_	3	并列关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 12, 'content': '她于9月3日发动了对威克岛的袭击，随后加入了第38特遣部队，并参加了对菲律宾南部和琉球的袭击', 'date': ['9月3日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 7, 'name': '威克岛', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 15, 'name': '特遣部队', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 21, 'name': '菲律宾', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 24, 'name': '琉球', 'label': '地点'})]})
# 1	她	她	r	r	_	5	主谓关系	_	_
# 2	于	于	p	p	_	5	状中结构	_	_
# 3	9月	9月	nt	t	_	4	定中关系	_	_
# 4	3日	3日	nt	t	_	2	介宾关系	_	_
# 5	发动	发动	v	v	_	0	核心关系	_	_
# 6	了	了	u	u	_	5	右附加关系	_	_
# 7	对	对	p	p	_	10	定中关系	_	_
# 8	威克岛	威克岛	ns	ns	_	7	介宾关系	_	_
# 9	的	的	u	u	_	7	右附加关系	_	_
# 10	袭击	袭击	v	vn	_	5	动宾关系	_	_
# 11	，	，	wp	w	_	5	标点符号	_	_
# 12	随后	随后	d	d	_	13	状中结构	_	_
# 13	加入	加入	v	v	_	5	并列关系	_	_
# 14	了	了	u	u	_	13	右附加关系	_	_
# 15	第38	第38	m	m	_	16	定中关系	_	_
# 16	特遣部队	特遣部队	n	n	_	13	动宾关系	_	_
# 17	，	，	wp	w	_	5	标点符号	_	_
# 18	并	并	c	c	_	19	状中结构	_	_
# 19	参加	参加	v	v	_	5	并列关系	_	_
# 20	了	了	u	u	_	19	右附加关系	_	_
# 21	对	对	p	p	_	27	定中关系	_	_
# 22	菲律宾	菲律宾	ns	ns	_	23	定中关系	_	_
# 23	南部	南部	nd	f	_	21	介宾关系	_	_
# 24	和	和	c	c	_	25	左附加关系	_	_
# 25	琉球	琉球	ns	ns	_	23	并列关系	_	_
# 26	的	的	u	u	_	21	右附加关系	_	_
# 27	袭击	袭击	v	vn	_	19	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 13, 'content': '1944年10月至12月在菲律宾度过，首先支持莱特，然后支持民都洛登陆', 'date': ['1944年10月', '12月'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 4, 'name': '菲律宾', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 9, 'name': '莱特', 'label': '人物'}), defaultdict(<class 'list'>, {'uuid': 13, 'name': '民都洛', 'label': '地点'})]})
# 1	1944年10月	1944年10月	nt	t	_	2	状中结构	_	_
# 2	至	至	p	p	_	6	状中结构	_	_
# 3	12月	12月	nt	t	_	2	介宾关系	_	_
# 4	在	在	p	p	_	6	状中结构	_	_
# 5	菲律宾	菲律宾	ns	ns	_	4	介宾关系	_	_
# 6	度过	度过	v	v	_	0	核心关系	_	_
# 7	，	，	wp	w	_	6	标点符号	_	_
# 8	首先	首先	d	d	_	9	状中结构	_	_
# 9	支持	支持	v	v	_	6	并列关系	_	_
# 10	莱特	莱特	nh	nrf	_	9	动宾关系	_	_
# 11	，	，	wp	w	_	9	标点符号	_	_
# 12	然后	然后	c	c	_	13	状中结构	_	_
# 13	支持	支持	v	v	_	9	并列关系	_	_
# 14	民都洛	民都洛	ns	ns	_	13	兼语	_	_
# 15	登陆	登陆	v	v	_	13	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 14, 'content': '尽管敌机无法摧毁蒙特利，但她并没有毫发无损地完成第一年的服役', 'date': [], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 1, 'name': '敌机', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 4, 'name': '蒙特利', 'label': '人物'})]})
# 1	尽管	尽管	c	c	_	4	状中结构	_	_
# 2	敌机	敌机	n	n	_	4	主谓关系	_	_
# 3	无法	无法	v	v	_	4	状中结构	_	_
# 4	摧毁	摧毁	v	v	_	0	核心关系	_	_
# 5	蒙特利	蒙特利	nh	nrf	_	4	动宾关系	_	_
# 6	，	，	wp	w	_	4	标点符号	_	_
# 7	但	但	c	c	_	13	状中结构	_	_
# 8	她	她	r	r	_	13	主谓关系	_	_
# 9	并	并	d	d	_	13	状中结构	_	_
# 10	没有	没有	d	d	_	13	状中结构	_	_
# 11	毫发无损	毫发无损	i	l	_	13	状中结构	_	_
# 12	地	地	u	u	_	11	右附加关系	_	_
# 13	完成	完成	v	v	_	4	并列关系	_	_
# 14	第一	第一	m	m	_	15	定中关系	_	_
# 15	年	年	q	q	_	17	定中关系	_	_
# 16	的	的	u	u	_	15	右附加关系	_	_
# 17	服役	服役	v	vn	_	13	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 15, 'content': '去年12月，她驶进了一条呼啸的台风路径，风速超过100节', 'date': ['年12月'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 6, 'name': '一条', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 9, 'name': '台风', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 10, 'name': '路径', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 12, 'name': '风速', 'label': '候选'})]})
# 1	去年	去年	nt	t	_	2	定中关系	_	_
# 2	12月	12月	nt	t	_	5	状中结构	_	_
# 3	，	，	wp	w	_	2	标点符号	_	_
# 4	她	她	r	r	_	5	主谓关系	_	_
# 5	驶进	驶进	v	v	_	0	核心关系	_	_
# 6	了	了	u	u	_	5	右附加关系	_	_
# 7	一条	一条	n	n	_	8	主谓关系	_	_
# 8	呼啸	呼啸	v	v	_	11	定中关系	_	_
# 9	的	的	u	u	_	8	右附加关系	_	_
# 10	台风	台风	n	n	_	11	定中关系	_	_
# 11	路径	路径	n	n	_	5	动宾关系	_	_
# 12	，	，	wp	w	_	5	标点符号	_	_
# 13	风速	风速	n	n	_	14	主谓关系	_	_
# 14	超过	超过	v	v	_	5	并列关系	_	_
# 15	100	100	m	m	_	16	定中关系	_	_
# 16	节	节	q	q	_	14	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 16, 'content': '风暴持续了两天之久，在最高峰时，几架飞机从缆绳上脱落，导致机库甲板上发生了几起火灾', 'date': [], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 0, 'name': '风暴', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 7, 'name': '最高峰', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 11, 'name': '架飞机', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 13, 'name': '缆绳', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 18, 'name': '机库', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 19, 'name': '甲板', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 25, 'name': '火灾', 'label': '候选'})]})
# 1	风暴	风暴	n	n	_	2	主谓关系	_	_
# 2	持续	持续	v	v	_	0	核心关系	_	_
# 3	了	了	u	u	_	2	右附加关系	_	_
# 4	两天	两天	nt	t	_	5	定中关系	_	_
# 5	之久	之久	r	r	_	2	动宾关系	_	_
# 6	，	，	wp	w	_	2	标点符号	_	_
# 7	在	在	p	p	_	16	状中结构	_	_
# 8	最高峰	最高峰	n	n	_	7	介宾关系	_	_
# 9	时	时	Ng	Ng	_	7	介宾关系	_	_
# 10	，	，	wp	w	_	7	标点符号	_	_
# 11	几	几	m	m	_	12	定中关系	_	_
# 12	架飞机	架飞机	n	n	_	16	主谓关系	_	_
# 13	从	从	p	p	_	16	状中结构	_	_
# 14	缆绳	缆绳	n	n	_	15	定中关系	_	_
# 15	上	上	nd	f	_	13	介宾关系	_	_
# 16	脱落	脱落	v	v	_	2	并列关系	_	_
# 17	，	，	wp	w	_	2	标点符号	_	_
# 18	导致	导致	v	v	_	2	并列关系	_	_
# 19	机库	机库	n	n	_	20	定中关系	_	_
# 20	甲板	甲板	n	n	_	21	定中关系	_	_
# 21	上	上	nd	f	_	22	状中结构	_	_
# 22	发生	发生	v	v	_	18	动宾关系	_	_
# 23	了	了	u	u	_	22	右附加关系	_	_
# 24	几	几	m	m	_	25	定中关系	_	_
# 25	起	起	q	q	_	26	定中关系	_	_
# 26	火灾	火灾	n	n	_	22	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 17, 'content': '1945年1月，蒙特利抵达华盛顿州布雷默顿进行大修', 'date': ['1945年1月'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 2, 'name': '蒙特利', 'label': '人物'}), defaultdict(<class 'list'>, {'uuid': 4, 'name': '华盛顿州布雷默顿', 'label': '地点'})]})
# 1	1945年1月	1945年1月	nt	t	_	4	状中结构	_	_
# 2	，	，	wp	w	_	1	标点符号	_	_
# 3	蒙特利	蒙特利	nh	nrf	_	4	主谓关系	_	_
# 4	抵达	抵达	v	v	_	0	核心关系	_	_
# 5	华盛顿州布雷默顿	华盛顿州布雷默顿	ns	ns	_	4	动宾关系	_	_
# 6	进行	进行	v	v	_	4	并列关系	_	_
# 7	大修	大修	v	vn	_	6	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 18, 'content': '她从5月9日至6月1日重新加入58特遣部队，并支持冲绳的行动，对N ansei Shoto和d Kyushu发动了打击', 'date': ['5月9日', '6月1日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 7, 'name': '重新加入', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 9, 'name': '特遣部队', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 13, 'name': '冲绳', 'label': '地点'})]})
# 1	她	她	r	r	_	10	定中关系	_	_
# 2	从	从	p	p	_	5	状中结构	_	_
# 3	5月	5月	nt	t	_	4	定中关系	_	_
# 4	9日	9日	nt	t	_	2	介宾关系	_	_
# 5	至	至	p	p	_	10	定中关系	_	_
# 6	6月	6月	nt	t	_	5	介宾关系	_	_
# 7	1日	1日	nt	t	_	8	定中关系	_	_
# 8	重新加入	重新加入	n	n	_	10	定中关系	_	_
# 9	58	58	m	m	_	10	定中关系	_	_
# 10	特遣部队	特遣部队	n	n	_	13	主谓关系	_	_
# 11	，	，	wp	w	_	10	标点符号	_	_
# 12	并	并	c	c	_	13	状中结构	_	_
# 13	支持	支持	v	v	_	0	核心关系	_	_
# 14	冲绳	冲绳	ns	ns	_	16	定中关系	_	_
# 15	的	的	u	u	_	14	右附加关系	_	_
# 16	行动	行动	v	vn	_	13	动宾关系	_	_
# 17	，	，	wp	w	_	13	标点符号	_	_
# 18	对N ansei Shoto和d Kyushu	对N ansei Shoto和d Kyushu	d	d	_	19	状中结构	_	_
# 19	发动	发动	v	v	_	13	并列关系	_	_
# 20	了	了	u	u	_	19	右附加关系	_	_
# 21	打击	打击	v	v	_	19	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 19, 'content': '7月1日至8月15日，她重返38特遣部队，参加了对本州和北海道的最后一次打击', 'date': ['7月1日', '8月15日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 8, 'name': '特遣部队', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 15, 'name': '北海道', 'label': '地点'})]})
# 1	7月	7月	nt	t	_	2	定中关系	_	_
# 2	1日	1日	nt	t	_	3	状中结构	_	_
# 3	至	至	p	p	_	7	状中结构	_	_
# 4	8月15日	8月15日	nt	t	_	3	介宾关系	_	_
# 5	，	，	wp	w	_	3	标点符号	_	_
# 6	她	她	r	r	_	7	主谓关系	_	_
# 7	重返	重返	v	v	_	0	核心关系	_	_
# 8	38	38	m	m	_	9	定中关系	_	_
# 9	特遣部队	特遣部队	n	n	_	7	动宾关系	_	_
# 10	，	，	wp	w	_	7	标点符号	_	_
# 11	参加	参加	v	v	_	7	并列关系	_	_
# 12	了	了	u	u	_	11	右附加关系	_	_
# 13	对	对	p	p	_	21	定中关系	_	_
# 14	本州	本州	r	r	_	13	介宾关系	_	_
# 15	和	和	c	c	_	16	左附加关系	_	_
# 16	北海道	北海道	ns	ns	_	14	并列关系	_	_
# 17	的	的	u	u	_	13	右附加关系	_	_
# 18	最后	最后	nd	f	_	19	定中关系	_	_
# 19	一	一	m	m	_	20	定中关系	_	_
# 20	次	次	q	q	_	21	状中结构	_	_
# 21	打击	打击	v	v	_	11	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 20, 'content': '她于9月7日离开日本水域，在东京出兵，然后清蒸回家，10月17日抵达纽约市', 'date': ['9月7日', '10月17日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 5, 'name': '日本', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 6, 'name': '水域', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 9, 'name': '东京', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 18, 'name': '纽约市', 'label': '地点'})]})
# 1	她	她	r	r	_	5	主谓关系	_	_
# 2	于	于	p	p	_	5	状中结构	_	_
# 3	9月	9月	nt	t	_	4	定中关系	_	_
# 4	7日	7日	nt	t	_	2	介宾关系	_	_
# 5	离开	离开	v	v	_	0	核心关系	_	_
# 6	日本	日本	ns	ns	_	7	定中关系	_	_
# 7	水域	水域	n	n	_	5	动宾关系	_	_
# 8	，	，	wp	w	_	5	标点符号	_	_
# 9	在	在	p	p	_	11	状中结构	_	_
# 10	东京	东京	ns	ns	_	9	介宾关系	_	_
# 11	出兵	出兵	v	v	_	5	并列关系	_	_
# 12	，	，	wp	w	_	5	标点符号	_	_
# 13	然后	然后	c	c	_	14	状中结构	_	_
# 14	清蒸	清蒸	v	v	_	5	并列关系	_	_
# 15	回家	回家	v	v	_	14	动宾关系	_	_
# 16	，	，	wp	w	_	5	标点符号	_	_
# 17	10月17日	10月17日	nt	t	_	18	状中结构	_	_
# 18	抵达	抵达	v	v	_	5	并列关系	_	_
# 19	纽约市	纽约市	ns	ns	_	18	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 21, 'content': '蒙特利留下了令人印象深刻、令人羡慕的战绩', 'date': [], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 0, 'name': '蒙特利', 'label': '人物'}), defaultdict(<class 'list'>, {'uuid': 3, 'name': '令人', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 4, 'name': '印象', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 9, 'name': '战绩', 'label': '候选'})]})
# 1	蒙特利	蒙特利	nh	nrf	_	2	主谓关系	_	_
# 2	留下	留下	v	v	_	0	核心关系	_	_
# 3	了	了	u	u	_	2	右附加关系	_	_
# 4	令人	令人	n	n	_	10	定中关系	_	_
# 5	印象	印象	n	n	_	6	主谓关系	_	_
# 6	深刻	深刻	a	a	_	10	定中关系	_	_
# 7	、	、	wp	w	_	8	标点符号	_	_
# 8	令人羡慕	令人羡慕	i	l	_	6	并列关系	_	_
# 9	的	的	u	u	_	6	右附加关系	_	_
# 10	战绩	战绩	n	n	_	2	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 22, 'content': '她的飞机击沉了五艘敌舰，并损坏了其他战舰', 'date': [], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 2, 'name': '飞机', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 13, 'name': '战舰', 'label': '候选'})]})
# 1	她	她	r	r	_	3	定中关系	_	_
# 2	的	的	u	u	_	1	右附加关系	_	_
# 3	飞机	飞机	n	n	_	4	主谓关系	_	_
# 4	击沉	击沉	v	v	_	0	核心关系	_	_
# 5	了	了	u	u	_	4	右附加关系	_	_
# 6	五	五	m	m	_	7	定中关系	_	_
# 7	艘	艘	q	q	_	8	定中关系	_	_
# 8	敌舰	敌舰	Ng	Ng	_	4	动宾关系	_	_
# 9	，	，	wp	w	_	4	标点符号	_	_
# 10	并	并	c	c	_	11	状中结构	_	_
# 11	损坏	损坏	v	v	_	4	并列关系	_	_
# 12	了	了	u	u	_	11	右附加关系	_	_
# 13	其他	其他	r	r	_	14	定中关系	_	_
# 14	战舰	战舰	n	n	_	11	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 23, 'content': '她负责摧毁数千吨日本船只、数百架飞机和重要的工业综合体', 'date': [], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 5, 'name': '日本', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 6, 'name': '船只', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 9, 'name': '架飞机', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 13, 'name': '工业', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 14, 'name': '综合体', 'label': '候选'})]})
# 1	她	她	r	r	_	2	主谓关系	_	_
# 2	负责	负责	v	v	_	0	核心关系	_	_
# 3	摧毁	摧毁	v	v	_	2	动宾关系	_	_
# 4	数千	数千	m	m	_	5	定中关系	_	_
# 5	吨	吨	q	q	_	7	定中关系	_	_
# 6	日本	日本	ns	ns	_	7	定中关系	_	_
# 7	船只	船只	n	n	_	3	动宾关系	_	_
# 8	、	、	wp	w	_	10	标点符号	_	_
# 9	数百	数百	m	m	_	10	定中关系	_	_
# 10	架飞机	架飞机	n	n	_	7	并列关系	_	_
# 11	和	和	c	c	_	15	左附加关系	_	_
# 12	重要	重要	a	a	_	15	定中关系	_	_
# 13	的	的	u	u	_	12	右附加关系	_	_
# 14	工业	工业	n	n	_	15	定中关系	_	_
# 15	综合体	综合体	n	n	_	7	并列关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 24, 'content': '她被分配到“魔毯”任务，并在那不勒斯和诺福克之间进行了几次航行', 'date': [], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 5, 'name': '魔毯', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 7, 'name': '任务', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 11, 'name': '那不勒斯', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 13, 'name': '诺福克', 'label': '地点'})]})
# 1	她	她	r	r	_	3	前置宾语	_	_
# 2	被	被	p	p	_	3	状中结构	_	_
# 3	分配	分配	v	v	_	0	核心关系	_	_
# 4	到	到	v	v	_	3	动补结构	_	_
# 5	“	“	wp	w	_	6	标点符号	_	_
# 6	魔毯	魔毯	n	n	_	8	定中关系	_	_
# 7	”	”	wp	w	_	6	标点符号	_	_
# 8	任务	任务	n	n	_	4	介宾关系	_	_
# 9	，	，	wp	w	_	3	标点符号	_	_
# 10	并	并	c	c	_	16	状中结构	_	_
# 11	在	在	p	p	_	16	状中结构	_	_
# 12	那不勒斯	那不勒斯	ns	ns	_	15	定中关系	_	_
# 13	和	和	c	c	_	14	左附加关系	_	_
# 14	诺福克	诺福克	ns	ns	_	12	并列关系	_	_
# 15	之间	之间	nd	f	_	11	介宾关系	_	_
# 16	进行	进行	v	v	_	3	并列关系	_	_
# 17	了	了	u	u	_	16	右附加关系	_	_
# 18	几	几	m	m	_	19	定中关系	_	_
# 19	次	次	q	q	_	20	状中结构	_	_
# 20	航行	航行	v	vn	_	16	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 25, 'content': '她于1947年2月11日退役，并被分配到费城大西洋后备舰队', 'date': ['1947年2月11日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 9, 'name': '费城大西洋', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 11, 'name': '舰队', 'label': '候选'})]})
# 1	她	她	r	r	_	4	主谓关系	_	_
# 2	于	于	p	p	_	4	状中结构	_	_
# 3	1947年2月11日	1947年2月11日	nt	t	_	2	介宾关系	_	_
# 4	退役	退役	v	vn	_	0	核心关系	_	_
# 5	，	，	wp	w	_	4	标点符号	_	_
# 6	并	并	c	c	_	8	状中结构	_	_
# 7	被	被	p	p	_	8	状中结构	_	_
# 8	分配	分配	v	v	_	4	并列关系	_	_
# 9	到	到	v	v	_	8	动补结构	_	_
# 10	费城大西洋	费城大西洋	ns	ns	_	12	定中关系	_	_
# 11	后备	后备	b	b	_	12	定中关系	_	_
# 12	舰队	舰队	n	n	_	9	介宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 26, 'content': '随着朝鲜战争的爆发，蒙特利于1950年9月15日重新投入使用', 'date': ['1950年9月15日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 1, 'name': '朝鲜', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 2, 'name': '战争', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 9, 'name': '投入使用', 'label': '候选'})]})
# 1	随着	随着	p	p	_	10	状中结构	_	_
# 2	朝鲜	朝鲜	ns	ns	_	3	定中关系	_	_
# 3	战争	战争	n	n	_	5	定中关系	_	_
# 4	的	的	u	u	_	3	右附加关系	_	_
# 5	爆发	爆发	v	vn	_	1	介宾关系	_	_
# 6	，	，	wp	w	_	1	标点符号	_	_
# 7	蒙特利于	蒙特利于	v	v	_	8	定中关系	_	_
# 8	1950年9月15日	1950年9月15日	nt	t	_	10	定中关系	_	_
# 9	重新	重新	d	d	_	10	状中结构	_	_
# 10	投入使用	投入使用	n	n	_	0	核心关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 27, 'content': '她于1951年1月3日离开诺福克，前往佛罗里达州彭萨科拉，在海军训练司令部的领导下，在那里工作了4年，训练了数千名海军航空学员、学生飞行员和直升机学员', 'date': ['1951年1月3日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 4, 'name': '诺福克', 'label': '武器'}), defaultdict(<class 'list'>, {'uuid': 7, 'name': '佛罗里达州', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 8, 'name': '彭萨科拉', 'label': '人物'}), defaultdict(<class 'list'>, {'uuid': 11, 'name': '海军', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 13, 'name': '司令部', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 28, 'name': '海军航空', 'label': '武器'}), defaultdict(<class 'list'>, {'uuid': 29, 'name': '学员', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 31, 'name': '学生', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 32, 'name': '飞行员', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 34, 'name': '直升机', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 35, 'name': '学员', 'label': '候选'})]})
# 1	她	她	r	r	_	4	主谓关系	_	_
# 2	于	于	p	p	_	4	状中结构	_	_
# 3	1951年1月3日	1951年1月3日	nt	t	_	2	介宾关系	_	_
# 4	离开	离开	v	v	_	0	核心关系	_	_
# 5	诺福克	诺福克	nz	nz	_	4	动宾关系	_	_
# 6	，	，	wp	w	_	4	标点符号	_	_
# 7	前往	前往	v	v	_	4	并列关系	_	_
# 8	佛罗里达州	佛罗里达州	ns	ns	_	7	动宾关系	_	_
# 9	彭萨科拉	彭萨科拉	nh	nrf	_	7	动宾关系	_	_
# 10	，	，	wp	w	_	4	标点符号	_	_
# 11	在	在	p	p	_	21	状中结构	_	_
# 12	海军	海军	n	n	_	11	介宾关系	_	_
# 13	训练	训练	v	vn	_	14	定中关系	_	_
# 14	司令部	司令部	n	n	_	16	定中关系	_	_
# 15	的	的	u	u	_	14	右附加关系	_	_
# 16	领导	领导	v	vn	_	17	定中关系	_	_
# 17	下	下	nd	f	_	11	介宾关系	_	_
# 18	，	，	wp	w	_	11	标点符号	_	_
# 19	在	在	p	p	_	21	状中结构	_	_
# 20	那里	那里	r	r	_	19	介宾关系	_	_
# 21	工作	工作	v	v	_	4	并列关系	_	_
# 22	了	了	u	u	_	21	右附加关系	_	_
# 23	4年	4年	nt	t	_	21	动宾关系	_	_
# 24	，	，	wp	w	_	21	标点符号	_	_
# 25	训练	训练	v	v	_	21	并列关系	_	_
# 26	了	了	u	u	_	25	右附加关系	_	_
# 27	数千	数千	m	m	_	28	定中关系	_	_
# 28	名	名	q	q	_	30	定中关系	_	_
# 29	海军航空	海军航空	nz	nz	_	30	定中关系	_	_
# 30	学员	学员	n	n	_	25	动宾关系	_	_
# 31	、	、	wp	w	_	33	标点符号	_	_
# 32	学生	学生	n	n	_	33	定中关系	_	_
# 33	飞行员	飞行员	n	n	_	30	并列关系	_	_
# 34	和	和	c	c	_	36	左附加关系	_	_
# 35	直升机	直升机	n	n	_	36	定中关系	_	_
# 36	学员	学员	n	n	_	30	并列关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 28, 'content': '1954年10月1日至11日，她参加了洪都拉斯的一次洪灾救援任务', 'date': ['1954年10月1日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 7, 'name': '洪都拉斯', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 12, 'name': '任务', 'label': '候选'})]})
# 1	1954年10月1日	1954年10月1日	nt	t	_	2	状中结构	_	_
# 2	至	至	p	p	_	6	状中结构	_	_
# 3	11日	11日	nt	t	_	2	介宾关系	_	_
# 4	，	，	wp	w	_	2	标点符号	_	_
# 5	她	她	r	r	_	6	主谓关系	_	_
# 6	参加	参加	v	v	_	0	核心关系	_	_
# 7	了	了	u	u	_	6	右附加关系	_	_
# 8	洪都拉斯	洪都拉斯	ns	ns	_	13	定中关系	_	_
# 9	的	的	u	u	_	8	右附加关系	_	_
# 10	一次	一次	m	m	_	11	定中关系	_	_
# 11	洪灾	洪灾	q	q	_	13	定中关系	_	_
# 12	救援	救援	v	vn	_	13	定中关系	_	_
# 13	任务	任务	n	n	_	6	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 29, 'content': '她于1955年6月9日离开彭萨科拉，重新加入费城大西洋预备舰队', 'date': ['1955年6月9日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 4, 'name': '彭萨科拉', 'label': '人物'}), defaultdict(<class 'list'>, {'uuid': 6, 'name': '重新加入', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 7, 'name': '费城大西洋', 'label': '地点'}), defaultdict(<class 'list'>, {'uuid': 9, 'name': '舰队', 'label': '候选'})]})
# 1	她	她	r	r	_	4	主谓关系	_	_
# 2	于	于	p	p	_	4	状中结构	_	_
# 3	1955年6月9日	1955年6月9日	nt	t	_	2	介宾关系	_	_
# 4	离开	离开	v	v	_	0	核心关系	_	_
# 5	彭萨科拉	彭萨科拉	nh	nrf	_	4	动宾关系	_	_
# 6	，	，	wp	w	_	4	标点符号	_	_
# 7	重新加入	重新加入	n	n	_	8	定中关系	_	_
# 8	费城大西洋	费城大西洋	ns	ns	_	10	定中关系	_	_
# 9	预备	预备	v	vn	_	10	定中关系	_	_
# 10	舰队	舰队	n	n	_	4	并列关系	_	_
#
#
#
# Not a sub-event
# defaultdict(<class 'list'>, {'uuid': 31, 'content': '1959年5月15日，她被重新归类为AVT-2，直到1969年仍在费城停泊', 'date': ['1959年5月15日'], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 10, 'name': 'AVT', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 19, 'name': '费城', 'label': '地点'})]})
# 1	1959	1959	m	m	_	2	定中关系	_	_
# 2	年	年	q	q	_	3	定中关系	_	_
# 3	5月	5月	nt	t	_	4	定中关系	_	_
# 4	15日	15日	nt	t	_	9	状中结构	_	_
# 5	，	，	wp	w	_	4	标点符号	_	_
# 6	她	她	r	r	_	9	前置宾语	_	_
# 7	被	被	p	p	_	9	状中结构	_	_
# 8	重新	重新	d	d	_	9	状中结构	_	_
# 9	归类	归类	v	v	_	0	核心关系	_	_
# 10	为	为	p	p	_	9	动补结构	_	_
# 11	AVT	AVT	ws	nx	_	10	介宾关系	_	_
# 12	-	-	wp	w	_	9	标点符号	_	_
# 13	2	2	m	m	_	9	并列关系	_	_
# 14	，	，	wp	w	_	13	标点符号	_	_
# 15	直到	直到	v	v	_	21	状中结构	_	_
# 16	1969	1969	m	m	_	17	定中关系	_	_
# 17	年	年	q	q	_	15	介宾关系	_	_
# 18	仍	仍	d	d	_	21	状中结构	_	_
# 19	在	在	p	p	_	21	状中结构	_	_
# 20	费城	费城	ns	ns	_	19	介宾关系	_	_
# 21	停泊	停泊	v	v	_	9	并列关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 32, 'content': '蒙特利在第二次世界大战中获得了11颗战斗之星', 'date': [], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 0, 'name': '蒙特利', 'label': '人物'}), defaultdict(<class 'list'>, {'uuid': 2, 'name': '第二次世界大战', 'label': '武器'}), defaultdict(<class 'list'>, {'uuid': 10, 'name': '星', 'label': '候选'})]})
# 1	蒙特利	蒙特利	nh	nrf	_	5	主谓关系	_	_
# 2	在	在	p	p	_	5	状中结构	_	_
# 3	第二次世界大战	第二次世界大战	nz	nz	_	4	定中关系	_	_
# 4	中	中	nd	f	_	2	介宾关系	_	_
# 5	获得	获得	v	v	_	0	核心关系	_	_
# 6	了	了	u	u	_	5	右附加关系	_	_
# 7	11	11	m	m	_	8	定中关系	_	_
# 8	颗	颗	q	q	_	11	定中关系	_	_
# 9	战斗	战斗	v	v	_	11	定中关系	_	_
# 10	之	之	u	u	_	9	右附加关系	_	_
# 11	星	星	n	n	_	5	动宾关系	_	_
#
#
#
# defaultdict(<class 'list'>, {'uuid': 33, 'content': '由Michael Hansen 72667.1530@compuserve.com转录', 'date': [], 'relationEntity': [defaultdict(<class 'list'>, {'uuid': 3, 'name': 'compuserve.com', 'label': '候选'}), defaultdict(<class 'list'>, {'uuid': 4, 'name': '转录', 'label': '候选'})]})
# 1	由	由	p	p	_	0	核心关系	_	_
# 2	Michael Hansen 72667.1530	Michael Hansen 72667.1530	m	m	_	3	定中关系	_	_
# 3	@	@	q	q	_	4	定中关系	_	_
# 4	compuserve.com	compuserve.com	ws	nx	_	5	定中关系	_	_
# 5	转录	转录	n	n	_	1	介宾关系	_	_

# %% [markdown]
# ## 保存子事件

# %%
with open('extraction.json', 'w', encoding='utf-8') as f:
    json.dump(result, f)

# %% [markdown]
# # 处理日期，进行日期关联排序建立事件之间的连接

# %%
# 没有年份的日期，取前一事件的年份作为年份
# 双日期取舍，选字符串长度长的，可能有更精确的时间
temp = deepcopy(result)
event_with_date = [r for r in temp if r['date']]
for each in event_with_date:
    if len(each['date']) > 1:
        temp_date = sorted(each['date'], key=len)[-1]
        each['date'] = [temp_date]

# %%
for index, each in enumerate(event_with_date):
    if each['date'][0].find('年') == -1:
        year = event_with_date[index-1]['date'][0].split('年')[0]
        each['date'].append(year + '年' + each['date'][0])
        each['date'].pop(0)
    if each['date'][0].startswith('年'):
        year = event_with_date[index-1]['date'][0].split('年')[0]
        each['date'].append(year + each['date'][0])
        each['date'].pop(0)
        
event_with_date
# 少日期的补上为每个月第一天，方便排序
for each in event_with_date:
    if not each['date'][0].endswith('日'):
        each['date'][0] += '1日'

# %%
sorted_date = sorted([r['date'][0] for r in event_with_date], 
       key=lambda x: datetime.datetime.strptime(x, '%Y年%m月%d日'))

# %%
# 基本是和行文的时间顺序一样
sorted_id = []
for date in sorted_date:
    for event in event_with_date:
        if event['date'][0] == date:
            sorted_id.append(event['uuid'])

# %%
relation_id = [{'startId': r[0], 'endId': r[1]} for r in zip(sorted_id, sorted_id[1:])]
relation_id
# Out:
# [{'startId': 0, 'endId': 1},
#  {'startId': 1, 'endId': 2},
#  {'startId': 2, 'endId': 3},
#  {'startId': 3, 'endId': 5},
#  {'startId': 5, 'endId': 6},
#  {'startId': 6, 'endId': 7},
#  {'startId': 7, 'endId': 9},
#  {'startId': 9, 'endId': 8},
#  {'startId': 8, 'endId': 10},
#  {'startId': 10, 'endId': 11},
#  {'startId': 11, 'endId': 12},
#  {'startId': 12, 'endId': 13},
#  {'startId': 13, 'endId': 15},
#  {'startId': 15, 'endId': 17},
#  {'startId': 17, 'endId': 18},
#  {'startId': 18, 'endId': 19},
#  {'startId': 19, 'endId': 20},
#  {'startId': 20, 'endId': 25},
#  {'startId': 25, 'endId': 26},
#  {'startId': 26, 'endId': 27},
#  {'startId': 27, 'endId': 28},
#  {'startId': 28, 'endId': 29},
#  {'startId': 29, 'endId': 31}]

# %% [markdown]
# ## 保存日期链接

# %%
with open('event_relation.json', 'w', encoding='utf-8') as f:
    json.dump(relation_id, f)

# %% [markdown]
# # todo
# - 指代消歧

# %% [markdown]
# # navigator

# %%
text1='2016年7月10日'
text2='2016年6月01日'
text3='2016年7月'
text = [text1, text2, text3]

# %%
sorted(text, key=lambda x: datetime.datetime.strptime(x, '%Y年%m月%d日'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-274-f72917f808b8> in <module>
# ----> 1 sorted(text, key=lambda x: datetime.datetime.strptime(x, '%Y年%m月%d日'))
#
# <ipython-input-274-f72917f808b8> in <lambda>(x)
# ----> 1 sorted(text, key=lambda x: datetime.datetime.strptime(x, '%Y年%m月%d日'))
#
# ~/anaconda3/envs/nlp/lib/python3.6/_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# ~/anaconda3/envs/nlp/lib/python3.6/_strptime.py in _strptime(data_string, format)
#     360     if not found:
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#     364         raise ValueError("unconverted data remains: %s" %
#
# ValueError: time data '2016年7月' does not match format '%Y年%m月%d日'
